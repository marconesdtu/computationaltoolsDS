# %%
import pandas as pd
from collections import defaultdict
import re

# Convert to DataFrame for easier processing
df = pd.read_csv('C:\\Users\\17675\\Downloads\\medicine_details.csv')

# Step 1: Define a regex pattern for splitting side effects
def split_side_effects(side_effects):
    # Regular expression to match words starting with uppercase letters (and followed by lowercase letters)
    return re.findall(r'[A-Z][a-z]*\s?[a-z]*', side_effects)

# Step 2: Prepare transactions (compositions and side effects)
transactions = defaultdict(set)  # To hold compositions
side_effects_dict = defaultdict(list)  # To hold side effects

for _, row in df.iterrows():
    # Each medicine is a transaction of components
    composition = row["Composition"].split(' + ')  # Split multiple ingredients
    transactions[row["Medicine Name"]] = composition
    # Store side effects associated with each medicine (using the regex split function)
    side_effects = split_side_effects(row["Side_effects"])
    side_effects_dict[row["Medicine Name"]] = side_effects

# %%
import re
from collections import Counter


def count_compositions(composition):

    components = composition.split('+')
    return len(components)


df['Composition Count'] = df['Composition'].apply(count_compositions)


composition_count_stats = df['Composition Count'].value_counts().sort_index()


print("Composition Count Statistics:")
print(composition_count_stats)
# Out:
# Composition Count Statistics:
# 1    7069
# 2    3596
# 3     933
# 4     150
# 5      51
# 6      16
# 7       7
# 8       2
# 9       1
# Name: Composition Count, dtype: int64

# %%
from itertools import combinations
# Apply A-Priori algorithm
def a_priori(transactions, min_support):
    item_counts = defaultdict(int)
    for transaction in transactions.values():
        for item in transaction:
            item_counts[item] += 1

    num_transactions = len(transactions)
    frequent_itemsets = {item: count / num_transactions for item, count in item_counts.items() if count / num_transactions >= min_support}

    current_itemsets = list(frequent_itemsets.keys())
    all_frequent_itemsets = dict(frequent_itemsets)

    k = 2
    while current_itemsets:
        next_itemsets = defaultdict(int)
        for transaction in transactions.values():
            for itemset in combinations(transaction, k):
                if all(item in transaction for item in itemset):
                    next_itemsets[itemset] += 1
        
        frequent_itemsets_k = {itemset: count / num_transactions for itemset, count in next_itemsets.items() if count / num_transactions >= min_support}
        
        if not frequent_itemsets_k:
            break
        
        all_frequent_itemsets.update(frequent_itemsets_k)
        current_itemsets = list(frequent_itemsets_k.keys())
        k += 1

    return all_frequent_itemsets

# Apply the A-Priori algorithm on the composition data
min_support = 0.001  #  support threshold

frequent_itemsets = a_priori(transactions, min_support)

# Show some of the frequent itemsets
for itemset, support in list(frequent_itemsets.items())[:5]:
    print(f"Itemset: {itemset} -> Support: {support:.4f}")
# Out:
# Itemset: Amoxycillin  (500mg) -> Support: 0.0034
# Itemset:  Clavulanic Acid (125mg) -> Support: 0.0047
# Itemset: Azithromycin (500mg) -> Support: 0.0025
# Itemset: Ambroxol (30mg/5ml) -> Support: 0.0038
# Itemset: Levosalbutamol (1mg/5ml) -> Support: 0.0027

# %%
from collections import defaultdict

itemset_side_effects = defaultdict(set)  

for medicine_name, components in transactions.items():
    side_effects = side_effects_dict[medicine_name]

    for itemset in frequent_itemsets:

        sorted_itemset = tuple(sorted(itemset)) 

        if all(item in components for item in itemset):
            itemset_side_effects[sorted_itemset].update(side_effects)  


for itemset, side_effects in itemset_side_effects.items():
    print(f"Itemset: {itemset} -> Associated Side Effects: {side_effects}")
# Out:
# Itemset: (' Clavulanic Acid (125mg)', 'Amoxycillin  (500mg)') -> Associated Side Effects: {'Nausea ', 'Diarrhea ', 'Mucocutaneous candidiasis', 'Vomiting '}
# Itemset: ('Ambroxol (30mg/5ml)', 'Levosalbutamol (1mg/5ml)') -> Associated Side Effects: {'Stomach pain', 'Bronchitis inflammation', 'Diarrhea ', 'Inflammation of', 'Palpitations ', 'Tremors ', 'Hives ', 'Pharyngitis', 'Rash ', 'Nausea ', 'Allergic reaction', 'Pain ', 'Dizziness ', 'Asthma ', 'Headache ', 'Upset stomach', 'Increased heart', 'Vomiting ', 'Muscle cramp'}
# Itemset: ('Ambroxol (30mg/5ml)', 'Guaifenesin (50mg/5ml)') -> Associated Side Effects: {'Palpitations', 'Stomach pain', 'Bronchitis inflammation', 'Diarrhea ', 'Inflammation of', 'Stomach discomfort', 'Palpitations ', 'Tremors ', 'Hives ', 'Pharyngitis', 'Rash ', 'Nausea ', 'Sleepiness', 'Allergic reaction', 'Pain ', 'Dizziness ', 'Asthma ', 'Headache ', 'Upset stomach', 'Increased heart', 'Vomiting ', 'Muscle cramp'}
# Itemset: ('Guaifenesin (50mg/5ml)', 'Levosalbutamol (1mg/5ml)') -> Associated Side Effects: {'Stomach pain', 'Bronchitis inflammation', 'Diarrhea ', 'Inflammation of', 'Palpitations ', 'Tremors ', 'Hives ', 'Pharyngitis', 'Rash ', 'Nausea ', 'Allergic reaction', 'Pain ', 'Dizziness ', 'Asthma ', 'Headache ', 'Upset stomach', 'Increased heart', 'Vomiting ', 'Muscle cramp'}
# Itemset: ('Ambroxol (30mg/5ml)', 'Guaifenesin (50mg/5ml)', 'Levosalbutamol (1mg/5ml)') -> Associated Side Effects: {'Stomach pain', 'Bronchitis inflammation', 'Diarrhea ', 'Inflammation of', 'Palpitations ', 'Tremors ', 'Hives ', 'Pharyngitis', 'Rash ', 'Nausea ', 'Allergic reaction', 'Pain ', 'Dizziness ', 'Asthma ', 'Headache ', 'Upset stomach', 'Increased heart', 'Vomiting ', 'Muscle cramp'}
# Itemset: ('Fexofenadine (120mg)', 'Montelukast (10mg)') -> Associated Side Effects: {'Increased transaminase', 'Diarrhea ', 'Constipation ', 'Heartburn ', 'Nasal inflammation', 'Abdominal discomfort', 'Dizziness', 'Esophageal bleeding', 'Drowsiness ', 'Upper respiratory', 'Rash ', 'Nausea ', 'Abdominal distension', 'Loss of', 'Increased white', 'Headache ', 'Vomiting ', 'Skin rash', 'Flu like'}
# Itemset: ('Chlorpheniramine Maleate (2mg)', 'Dextromethorphan Hydrobromide (10mg)') -> Associated Side Effects: {'Nausea ', 'Sleepiness', 'Headache', 'Upset stomach', 'Vomiting ', 'Loss of'}
# Itemset: ('Chlorpheniramine Maleate (2mg/5ml)', 'Phenylephrine (5mg/5ml)') -> Associated Side Effects: {'Headache', 'Diarrhea ', 'Restlessness ', 'Abdominal pain', 'Palpitations ', 'Insomnia difficulty', 'Tremors ', 'Blurred vision', 'High blood', 'Cerebral hemorrhage', 'Hallucination ', 'Rash', 'Tachycardia ', 'Pale skin', 'Rash ', 'Nausea ', 'Sleepiness', 'Seizure ', 'Convulsion', 'Loss of', 'Allergic reaction', 'Dizziness ', 'Headache ', 'Upset stomach', 'Anxiety ', 'Vomiting ', 'Paresthesia tingling', 'Dry throat', 'Weakness ', 'Dry nose', 'Fear ', 'Excitement ', 'Discomfort when', 'Decreased appetite'}
# Itemset: ('Dextromethorphan Hydrobromide (10mg/5ml)', 'Phenylephrine (5mg/5ml)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Sleepiness', 'Headache', 'Upset stomach', 'Stomach pain', 'Diarrhea ', 'Vomiting ', 'Insomnia difficulty', 'Loss of', 'Hives ', 'Dizziness ', 'Itching ', 'Rash '}
# Itemset: ('Chlorpheniramine Maleate (2mg/5ml)', 'Dextromethorphan Hydrobromide (10mg/5ml)') -> Associated Side Effects: {'Nausea ', 'Sleepiness', 'Headache ', 'Headache', 'Upset stomach', 'Vomiting ', 'Loss of'}
# Itemset: ('Chlorpheniramine Maleate (2mg/5ml)', 'Dextromethorphan Hydrobromide (10mg/5ml)', 'Phenylephrine (5mg/5ml)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Sleepiness', 'Headache', 'Upset stomach', 'Vomiting ', 'Loss of'}
# Itemset: (' Clavulanic Acid (28.5mg)', 'Amoxycillin  (200mg)') -> Associated Side Effects: {'Nausea ', 'Abdominal pain', 'Diarrhea ', 'Vomiting ', 'Allergy ', 'Mucocutaneous candidiasis'}
# Itemset: ('Aceclofenac (100mg)', 'Paracetamol (325mg)') -> Associated Side Effects: {'Stomach pain', 'Diarrhea ', 'Heartburn ', 'Diarrhea', 'Abdominal pain', 'Hives ', 'Indigestion ', 'Rash ', 'Nausea ', 'Drowsiness', 'Sleepiness', 'Tiredness ', 'Loss of', 'Dizziness ', 'Headache ', 'Vomiting ', 'Weakness ', 'Sleepiness ', 'Dryness in'}
# Itemset: ('Paracetamol (325mg)', 'Serratiopeptidase (10mg)') -> Associated Side Effects: {'Nausea ', 'Stomach pain', 'Vomiting ', 'Loss of', 'Heartburn ', 'Indigestion ', 'Diarrhea'}
# Itemset: ('Ambroxol (15mg/5ml)', 'Guaifenesin (50mg/5ml)') -> Associated Side Effects: {'Indigestion', 'Stomach pain', 'Bloating ', 'Diarrhea ', 'Stomach discomfort', 'Upper abdominal', 'Changes in', 'Fatigue ', 'Palpitations ', 'Excessive salivation', 'Tremors ', 'Hives ', 'Indigestion ', 'Rash ', 'Nausea ', 'Sleepiness', 'Allergic reaction', 'Dizziness ', 'Headache ', 'Urticaria ', 'Upset stomach', 'Increased heart', 'Vomiting ', 'Muscle cramp', 'Paresthesia tingling', 'Itching ', 'Sweating ', 'Dryness in', 'Arrhythmia irregular'}
# Itemset: ('Aceclofenac (100mg)', 'Serratiopeptidase (15mg)') -> Associated Side Effects: {'Nausea ', 'Stomach pain', 'Vomiting ', 'Loss of', 'Heartburn ', 'Indigestion ', 'Diarrhea'}
# Itemset: ('Paracetamol (325mg)', 'Serratiopeptidase (15mg)') -> Associated Side Effects: {'Nausea ', 'Stomach pain', 'Diarrhea ', 'Vomiting ', 'Loss of', 'Heartburn ', 'Indigestion ', 'Increased liver', 'Heartburn', 'Diarrhea'}
# Itemset: ('Aceclofenac (100mg)', 'Paracetamol (325mg)', 'Serratiopeptidase (15mg)') -> Associated Side Effects: {'Nausea ', 'Stomach pain', 'Vomiting ', 'Loss of', 'Heartburn ', 'Indigestion ', 'Diarrhea'}
# Itemset: ('Amlodipine (5mg)', 'Atenolol (50mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Tiredness ', 'Palpitations ', 'Edema swelling', 'Constipation ', 'Cold extremities', 'Flushing sense', 'Slow heart', 'Sleepiness ', 'Ankle swelling'}
# Itemset: ('Atorvastatin (10mg)', 'Clopidogrel (75mg)') -> Associated Side Effects: {'Headache ', 'Nosebleeds ', 'Abdominal pain', 'Stomach pain', 'Diarrhea ', 'Constipation ', 'Increased glucose', 'Gastrointestinal bleeding', 'Bruise ', 'Increased bleeding', 'Weakness ', 'Indigestion ', 'Increased liver', 'Muscle pain', 'Dizziness ', 'Diarrhea'}
# Itemset: ('Paracetamol (325mg)', 'Thiocolchicoside (4mg)') -> Associated Side Effects: {'Nausea ', 'Stomach pain', 'Diarrhea ', 'Vomiting ', 'Loss of', 'Heartburn ', 'Dryness in'}
# Itemset: ('Aceclofenac (100mg)', 'Thiocolchicoside (4mg)') -> Associated Side Effects: {'Nausea ', 'Stomach pain', 'Diarrhea ', 'Vomiting ', 'Loss of', 'Heartburn ', 'Dryness in', 'Diarrhea'}
# Itemset: ('Amlodipine (5mg)', 'Telmisartan (40mg)') -> Associated Side Effects: {'Increased uric', 'Increased glucose', 'Fatigue ', 'Palpitations ', 'Gastrointestinal disturbance', 'Impotence', 'Increased liver', 'Nausea ', 'Tiredness ', 'Edema swelling', 'Postural hypotension', 'Increased potassium', 'Dizziness ', 'Peripheral edema', 'Electrolyte imbalance', 'Mood changes', 'Headache ', 'Urticaria ', 'Upset stomach', 'Breathlessness ', 'Increased blood', 'Muscle cramp', 'Visual disturbance', 'Flushing sense', 'Sleepiness ', 'Ankle swelling'}
# Itemset: ('Hydrochlorothiazide (12.5mg)', 'Telmisartan (40mg)') -> Associated Side Effects: {'Nausea ', 'Sinus inflammation', 'Dizziness ', 'Fatigue ', 'Diarrhea ', 'Visual disturbance', 'Upper respiratory', 'Flu like', 'Ankle swelling', 'Peripheral edema', 'Mood changes'}
# Itemset: ('Amlodipine (5mg)', 'Hydrochlorothiazide (12.5mg)') -> Associated Side Effects: {'Diarrhea ', 'Altered blood', 'Fatigue ', 'Palpitations ', 'Urinary tract', 'Upper respiratory', 'Muscle spasm', 'Nausea ', 'Decreased potassium', 'Tiredness ', 'Taste change', 'Nasopharyngitis inflammation', 'Dizziness ', 'Peripheral edema', 'Mood changes', 'Headache ', 'Upset stomach', 'Increased blood', 'Glucose intolerance', 'Visual disturbance', 'Flushing sense', 'Sleepiness ', 'Ankle swelling', 'Joint swelling'}
# Itemset: ('Amlodipine (5mg)', 'Hydrochlorothiazide (12.5mg)', 'Telmisartan (40mg)') -> Associated Side Effects: {'Nausea ', 'Dizziness ', 'Visual disturbance', 'Ankle swelling', 'Peripheral edema', 'Mood changes'}
# Itemset: ('Methylcobalamin (1500mcg)', 'Pregabalin (75mg)') -> Associated Side Effects: {'Nausea ', 'Tiredness ', 'Increased heart', 'Difficulty in', 'Increased saliva', 'Constipation ', 'Orthostatic hypotension', 'Edema swelling', 'Blurred vision', 'Uncoordinated body', 'Impaired concentration', 'Sleepiness ', 'Dizziness ', 'Dryness in', 'Weight gain'}
# Itemset: ('Levocetirizine (5mg)', 'Montelukast (10mg)') -> Associated Side Effects: {'Nausea ', 'Flu like', 'Headache ', 'Fatigue ', 'Upset stomach', 'Diarrhea ', 'Allergic reaction', 'Vomiting', 'Skin rash', 'Sleepiness ', 'Dryness in'}
# Itemset: ('Cilnidipine (10mg)', 'Telmisartan (40mg)') -> Associated Side Effects: {'Diarrhea ', 'Constipation ', 'Decreased blood', 'Altered blood', 'Slow heart', 'Palpitations ', 'Nausea ', 'Numbness of', 'Tiredness ', 'Edema swelling', 'Taste change', 'Increased potassium', 'Dizziness ', 'Headache ', 'Upset stomach', 'Increased blood', 'Cold extremities', 'Glucose intolerance', 'Weakness ', 'Flushing sense', 'Sleepiness ', 'Ankle swelling'}
# Itemset: ('Metoprolol Succinate (50mg)', 'Telmisartan (40mg)') -> Associated Side Effects: {'Nausea ', 'Numbness of', 'Headache ', 'Diarrhea ', 'Constipation ', 'Edema swelling', 'Decreased blood', 'Cold extremities', 'Taste change', 'Weakness ', 'Increased potassium', 'Flushing sense', 'Slow heart', 'Ankle swelling', 'Dizziness '}
# Itemset: ('Glimepiride (1mg)', 'Metformin (500mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Abdominal pain', 'Flatulence ', 'Bronchitis inflammation', 'Diarrhea ', 'Anemia low', 'Edema swelling', 'Vomiting ', 'Flatulence', 'Hypoglycemia low', 'Dizziness '}
# Itemset: ('Adapalene (0.1% w/w)', 'Clindamycin (1% w/w)') -> Associated Side Effects: {'Burning sensation', 'Skin peeling', 'Dry skin', 'Erythema skin', 'Itching '}
# Itemset: ('Glimepiride (2mg)', 'Metformin (500mg)') -> Associated Side Effects: {'Nausea ', 'Respiratory tract', 'Headache ', 'Abdominal pain', 'Flatulence ', 'Bronchitis inflammation', 'Diarrhea ', 'Anemia low', 'Edema swelling', 'Vomiting ', 'Stomach pain', 'Taste change', 'Flatulence', 'Hypoglycemia low', 'Dizziness '}
# Itemset: ('Glimepiride (2mg)', 'Voglibose (0.2mg)') -> Associated Side Effects: {'Nausea ', 'Diarrhea ', 'Abdominal pain', 'Hypoglycemia low'}
# Itemset: ('Metformin (500mg)', 'Voglibose (0.2mg)') -> Associated Side Effects: {'Nausea ', 'Respiratory tract', 'Headache ', 'Abdominal pain', 'Stomach pain', 'Flatulence ', 'Diarrhea ', 'Bloating ', 'Vomiting ', 'Taste change', 'Hypoglycemia low', 'Skin rash', 'Decreased appetite'}
# Itemset: ('Glimepiride (2mg)', 'Metformin (500mg)', 'Voglibose (0.2mg)') -> Associated Side Effects: {'Nausea ', 'Diarrhea ', 'Abdominal pain', 'Hypoglycemia low'}
# Itemset: ('Atorvastatin (10mg)', 'Fenofibrate (160mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Flatulence ', 'Stomach pain', 'Constipation ', 'Increased glucose', 'Increased liver', 'Muscle pain'}
# Itemset: ('Atorvastatin (20mg)', 'Clopidogrel (75mg)') -> Associated Side Effects: {'Headache ', 'Nosebleeds ', 'Abdominal pain', 'Stomach pain', 'Diarrhea ', 'Constipation ', 'Increased glucose', 'Gastrointestinal bleeding', 'Bruise ', 'Increased bleeding', 'Weakness ', 'Indigestion ', 'Increased liver', 'Muscle pain', 'Dizziness ', 'Diarrhea'}
# Itemset: ('Guaifenesin (50mg/5ml)', 'Terbutaline (1.25mg/5ml)') -> Associated Side Effects: {'Indigestion', 'Palpitations', 'Stomach pain', 'Bloating ', 'Diarrhea ', 'Constipation ', 'Heartburn ', 'Nasal inflammation', 'Stomach discomfort', 'Upper abdominal', 'Changes in', 'Fatigue ', 'Excessive salivation', 'Tremors ', 'Trembling ', 'Hives ', 'Indigestion ', 'Drowsiness ', 'Rash ', 'Nausea ', 'Breathing problems', 'Loss of', 'Allergic reaction', 'Increased white', 'Dizziness ', 'Headache ', 'Urticaria ', 'Increased heart', 'Vomiting ', 'Paresthesia tingling', 'Itching ', 'Skin rash', 'Sweating ', 'Arrhythmia irregular'}
# Itemset: ('Glimepiride (1mg)', 'Voglibose (0.2mg)') -> Associated Side Effects: {'Nausea ', 'Diarrhea ', 'Abdominal pain', 'Hypoglycemia low'}
# Itemset: ('Glimepiride (1mg)', 'Metformin (500mg)', 'Voglibose (0.2mg)') -> Associated Side Effects: {'Nausea ', 'Diarrhea ', 'Abdominal pain', 'Hypoglycemia low'}
# Itemset: ('Domperidone (30mg)', 'Rabeprazole (20mg)') -> Associated Side Effects: {'Headache ', 'Stomach pain', 'Flatulence ', 'Diarrhea ', 'Weakness ', 'Flu like', 'Dizziness ', 'Dryness in'}
# Itemset: ('Metoprolol Succinate (25mg)', 'Telmisartan (40mg)') -> Associated Side Effects: {'Nausea ', 'Numbness of', 'Headache ', 'Diarrhea ', 'Constipation ', 'Edema swelling', 'Decreased blood', 'Cold extremities', 'Taste change', 'Weakness ', 'Increased potassium', 'Flushing sense', 'Slow heart', 'Ankle swelling', 'Dizziness '}
# Itemset: ('Amlodipine (5mg)', 'Losartan (50mg)') -> Associated Side Effects: {'Altered blood', 'Nasal congestion', 'Change in', 'Fatigue ', 'Abdominal pain', 'Palpitations ', 'Upper respiratory', 'Nausea ', 'Tiredness ', 'Edema swelling', 'Taste change', 'Increased potassium', 'Dizziness ', 'Headache ', 'Upset stomach', 'Breathlessness ', 'Increased blood', 'Glucose intolerance', 'Visual disturbance', 'Flushing sense', 'Sleepiness ', 'Ankle swelling'}
# Itemset: ('Glimepiride (2mg)', 'Metformin (1000mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Abdominal pain', 'Flatulence ', 'Bronchitis inflammation', 'Diarrhea ', 'Anemia low', 'Edema swelling', 'Vomiting ', 'Flatulence', 'Hypoglycemia low', 'Dizziness '}
# Itemset: ('Aspirin (75mg)', 'Clopidogrel (75mg)') -> Associated Side Effects: {'Nosebleeds ', 'Headache ', 'Abdominal pain', 'Nosebleeds', 'Diarrhea ', 'Gastrointestinal bleeding', 'Bruise ', 'Increased bleeding', 'Weakness ', 'Indigestion ', 'Nausea', 'Muscle pain', 'Diarrhea'}
# Itemset: ('Amlodipine (5mg)', 'Metoprolol Succinate (50mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Fatigue ', 'Abdominal pain', 'Palpitations ', 'Breathlessness ', 'Constipation ', 'Edema swelling', 'Vomiting ', 'Orthostatic hypotension', 'Muscle cramp', 'Visual disturbance', 'Ankle swelling', 'Flushing sense', 'Sleepiness ', 'Slow heart', 'Dizziness '}
# Itemset: ('Glimepiride (1mg)', 'Metformin (1000mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Abdominal pain', 'Flatulence ', 'Bronchitis inflammation', 'Diarrhea ', 'Anemia low', 'Edema swelling', 'Vomiting ', 'Flatulence', 'Hypoglycemia low', 'Dizziness '}
# Itemset: ('Adapalene (0.1% w/w)', 'Benzoyl Peroxide (2.5% w/w)') -> Associated Side Effects: {'Scaling ', 'Erythema skin', 'Burning sensation', 'Stinging sensation'}
# Itemset: ('Ketoconazole (2% w/v)', 'Zinc pyrithione (1% w/v)') -> Associated Side Effects: {'Application site'}
# Itemset: ('Nortriptyline (10mg)', 'Pregabalin (75mg)') -> Associated Side Effects: {'Tiredness ', 'Increased heart', 'Difficulty in', 'Constipation ', 'Orthostatic hypotension', 'Blurred vision', 'Uncoordinated body', 'Sleepiness ', 'Dizziness ', 'Dryness in', 'Weight gain'}
# Itemset: ('Domperidone (30mg)', 'Pantoprazole (40mg)') -> Associated Side Effects: {'Headache', 'Flatulence ', 'Stomach pain', 'Diarrhea ', 'Dizziness ', 'Dryness in'}
# Itemset: ('Chlorthalidone (12.5mg)', 'Telmisartan (40mg)') -> Associated Side Effects: {'Increased uric', 'Sinus infection', 'Diarrhea ', 'Increased glucose', 'Altered blood', 'Fatigue ', 'Palpitations ', 'Gastrointestinal disturbance', 'Impotence', 'Increased liver', 'Tiredness ', 'Edema swelling', 'Postural hypotension', 'Taste change', 'Dizziness ', 'Electrolyte imbalance', 'Headache ', 'Urticaria ', 'Upset stomach', 'Breathlessness ', 'Increased blood', 'Muscle cramp', 'Back pain', 'Glucose intolerance', 'Visual disturbance', 'Skin ulcer', 'Flushing sense', 'Sleepiness ', 'Ankle swelling'}
# Itemset: ('Bromelain (180mg)', 'Trypsin (96mg)') -> Associated Side Effects: {'Nausea ', 'Stomach pain', 'Diarrhea ', 'Loss of', 'Indigestion ', 'No common', 'Heartburn'}
# Itemset: ('Bromelain (180mg)', 'Rutoside (200mg)') -> Associated Side Effects: {'Nausea ', 'Stomach pain', 'Diarrhea ', 'Loss of', 'Indigestion ', 'No common', 'Heartburn'}
# Itemset: ('Rutoside (200mg)', 'Trypsin (96mg)') -> Associated Side Effects: {'Nausea ', 'Stomach pain', 'Diarrhea ', 'Loss of', 'Indigestion ', 'No common', 'Heartburn'}
# Itemset: ('Bromelain (180mg)', 'Rutoside (200mg)', 'Trypsin (96mg)') -> Associated Side Effects: {'Nausea ', 'Stomach pain', 'Diarrhea ', 'Loss of', 'Indigestion ', 'No common', 'Heartburn'}
# Itemset: ('Bromelain (90mg)', 'Trypsin (48mg)') -> Associated Side Effects: {'Nausea ', 'Stomach pain', 'Diarrhea ', 'Vomiting ', 'Loss of', 'Heartburn ', 'Indigestion ', 'No common', 'Diarrhea'}
# Itemset: ('Rutoside (100mg)', 'Trypsin (48mg)') -> Associated Side Effects: {'Nausea ', 'Stomach pain', 'Diarrhea ', 'Vomiting ', 'Loss of', 'Heartburn ', 'Indigestion ', 'No common', 'Diarrhea'}
# Itemset: ('Diclofenac (50mg)', 'Trypsin (48mg)') -> Associated Side Effects: {'Nausea ', 'Stomach pain', 'Diarrhea ', 'Vomiting ', 'Loss of', 'Heartburn ', 'Indigestion '}
# Itemset: ('Bromelain (90mg)', 'Rutoside (100mg)') -> Associated Side Effects: {'Nausea ', 'Indigestion', 'Stomach pain', 'Diarrhea ', 'Vomiting ', 'Loss of', 'Heartburn ', 'Indigestion ', 'No common', 'Diarrhea'}
# Itemset: ('Bromelain (90mg)', 'Diclofenac (50mg)') -> Associated Side Effects: {'Nausea ', 'Indigestion', 'Stomach pain', 'Diarrhea ', 'Vomiting ', 'Loss of', 'Heartburn ', 'Indigestion '}
# Itemset: ('Diclofenac (50mg)', 'Rutoside (100mg)') -> Associated Side Effects: {'Nausea ', 'Indigestion', 'Stomach pain', 'Diarrhea ', 'Vomiting ', 'Loss of', 'Heartburn ', 'Indigestion '}
# Itemset: ('Bromelain (90mg)', 'Rutoside (100mg)', 'Trypsin (48mg)') -> Associated Side Effects: {'Nausea ', 'Stomach pain', 'Diarrhea ', 'Vomiting ', 'Loss of', 'Heartburn ', 'Indigestion ', 'No common', 'Diarrhea'}
# Itemset: ('Bromelain (90mg)', 'Diclofenac (50mg)', 'Trypsin (48mg)') -> Associated Side Effects: {'Nausea ', 'Stomach pain', 'Diarrhea ', 'Vomiting ', 'Loss of', 'Heartburn ', 'Indigestion '}
# Itemset: ('Diclofenac (50mg)', 'Rutoside (100mg)', 'Trypsin (48mg)') -> Associated Side Effects: {'Nausea ', 'Stomach pain', 'Diarrhea ', 'Vomiting ', 'Loss of', 'Heartburn ', 'Indigestion '}
# Itemset: ('Bromelain (90mg)', 'Diclofenac (50mg)', 'Rutoside (100mg)') -> Associated Side Effects: {'Nausea ', 'Indigestion', 'Stomach pain', 'Diarrhea ', 'Vomiting ', 'Loss of', 'Heartburn ', 'Indigestion '}
# Itemset: ('Bromelain (90mg)', 'Diclofenac (50mg)', 'Rutoside (100mg)', 'Trypsin (48mg)') -> Associated Side Effects: {'Nausea ', 'Stomach pain', 'Diarrhea ', 'Vomiting ', 'Loss of', 'Heartburn ', 'Indigestion '}
# Itemset: ('Acebrophylline (200mg)', 'Montelukast (10mg)') -> Associated Side Effects: {'Increased transaminase', 'Stomach pain', 'Diarrhea ', 'Constipation ', 'Heartburn ', 'Nasal inflammation', 'Abdominal discomfort', 'Fatigue ', 'Esophageal bleeding', 'Hives ', 'Drowsiness ', 'Upper respiratory', 'Rash ', 'Nausea ', 'Breathing problems', 'Abdominal distension', 'Loss of', 'Increased white', 'Headache ', 'Vomiting ', 'Skin rash', 'Flu like', 'Dryness in', 'Itching '}
# Itemset: ('Glimepiride (2mg)', 'Voglibose (0.3mg)') -> Associated Side Effects: {'Nausea ', 'Diarrhea ', 'Abdominal pain', 'Hypoglycemia low'}
# Itemset: ('Metformin (500mg)', 'Voglibose (0.3mg)') -> Associated Side Effects: {'Nausea ', 'Respiratory tract', 'Headache ', 'Abdominal pain', 'Flatulence ', 'Bloating ', 'Diarrhea ', 'Stomach pain', 'Vomiting ', 'Taste change', 'Hypoglycemia low', 'Skin rash', 'Decreased appetite'}
# Itemset: ('Glimepiride (2mg)', 'Metformin (500mg)', 'Voglibose (0.3mg)') -> Associated Side Effects: {'Nausea ', 'Diarrhea ', 'Abdominal pain', 'Hypoglycemia low'}
# Itemset: ('Gliclazide (60mg)', 'Metformin (500mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Flatulence ', 'Bronchitis inflammation', 'Diarrhea ', 'Anemia low', 'Edema swelling', 'Vomiting ', 'Flatulence', 'Hypoglycemia low', 'Upper respiratory', 'Dizziness '}
# Itemset: ('Metformin (500mg)', 'Pioglitazone (15mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Flatulence ', 'Bronchitis inflammation', 'Diarrhea ', 'Anemia low', 'Edema swelling', 'Vomiting ', 'Urinary tract', 'Hypoglycemia low', 'Upper respiratory', 'Dizziness ', 'Weight gain'}
# Itemset: ('Fenofibrate (160mg)', 'Rosuvastatin (10mg)') -> Associated Side Effects: {'Headache ', 'Constipation ', 'Elevated creatine', 'Diabetes', 'Joint pain', 'Muscle pain', 'Abnormal liver'}
# Itemset: ('Hydroquinone (2% w/w)', 'Tretinoin (0.025% w/w)') -> Associated Side Effects: {'Burning sensation', 'Skin peeling', 'Dry skin', 'Application site', 'Thinning of', 'Itching', 'Dryness ', 'Erythema skin'}
# Itemset: ('Methylcobalamin (750mcg)', 'Pregabalin (75mg)') -> Associated Side Effects: {'Tiredness ', 'Uncoordinated body', 'Sleepiness ', 'Dizziness ', 'Abnormality of'}
# Itemset: ('Diclofenac (50mg)', 'Paracetamol (325mg)') -> Associated Side Effects: {'Nausea ', 'Sleepiness', 'Stomach pain', 'Diarrhea ', 'Vomiting ', 'Loss of', 'Blurred vision', 'Heartburn ', 'Indigestion ', 'Sleepiness ', 'Weakness', 'Dizziness ', 'Dryness in', 'Diarrhea'}
# Itemset: ('Diclofenac (50mg)', 'Serratiopeptidase (10mg)') -> Associated Side Effects: {'Nausea ', 'Stomach pain', 'Diarrhea ', 'Vomiting ', 'Loss of', 'Heartburn ', 'Indigestion ', 'Diarrhea'}
# Itemset: ('Gabapentin (400mg)', 'Nortriptyline (10mg)') -> Associated Side Effects: {'Tiredness ', 'Increased heart', 'Difficulty in', 'Constipation ', 'Orthostatic hypotension', 'Blurred vision', 'Uncoordinated body', 'Sleepiness ', 'Dizziness ', 'Dryness in', 'Weight gain'}
# Itemset: ('Levosulpiride (75mg)', 'Rabeprazole (20mg)') -> Associated Side Effects: {'Nausea ', 'Flu like', 'Headache ', 'Flatulence ', 'Stomach pain', 'Diarrhea ', 'Constipation ', 'Weakness ', 'Sleepiness ', 'Dizziness '}
# Itemset: ('Methylcobalamin (1500mcg)', 'Nortriptyline (10mg)') -> Associated Side Effects: {'Increased heart', 'Tiredness ', 'Difficulty in', 'Constipation ', 'Orthostatic hypotension', 'Blurred vision', 'Uncoordinated body', 'Sleepiness ', 'Dizziness ', 'Dryness in', 'Weight gain'}
# Itemset: ('Methylcobalamin (1500mcg)', 'Nortriptyline (10mg)', 'Pregabalin (75mg)') -> Associated Side Effects: {'Increased heart', 'Tiredness ', 'Difficulty in', 'Constipation ', 'Orthostatic hypotension', 'Blurred vision', 'Uncoordinated body', 'Sleepiness ', 'Dizziness ', 'Dryness in', 'Weight gain'}
# Itemset: ('Amlodipine (5mg)', 'Telmisartan (80mg)') -> Associated Side Effects: {'Increased uric', 'Increased glucose', 'Fatigue ', 'Palpitations ', 'Gastrointestinal disturbance', 'Impotence', 'Increased liver', 'Nausea ', 'Tiredness ', 'Edema swelling', 'Postural hypotension', 'Increased potassium', 'Dizziness ', 'Electrolyte imbalance', 'Peripheral edema', 'Mood changes', 'Headache ', 'Urticaria ', 'Upset stomach', 'Breathlessness ', 'Increased blood', 'Muscle cramp', 'Visual disturbance', 'Flushing sense', 'Sleepiness ', 'Ankle swelling'}
# Itemset: ('Doxylamine (10mg)', 'Vitamin B6 (Pyridoxine) (10mg)') -> Associated Side Effects: {'Drowsiness', 'Fatigue ', 'Constipation ', 'Lightheadedness ', 'Sleepiness ', 'Constipation', 'Dizziness ', 'Dryness in'}
# Itemset: ('Glimepiride (0.5mg)', 'Metformin (500mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Diarrhea ', 'Flatulence', 'Hypoglycemia low'}
# Itemset: ('Hydrochlorothiazide (12.5mg)', 'Losartan (50mg)') -> Associated Side Effects: {'Increased uric', 'Diarrhea ', 'Decreased blood', 'Altered blood', 'Slow heart', 'Palpitations ', 'Decreased sodium', 'Nausea ', 'Numbness of', 'Tiredness ', 'Taste change', 'Decreased magnesium', 'Dizziness ', 'Electrolyte imbalance', 'Headache ', 'Upset stomach', 'Increased blood', 'Cold extremities', 'Glucose intolerance', 'Weakness ', 'Flushing sense', 'Sleepiness ', 'Ankle swelling'}
# Itemset: ('Etoricoxib (60mg)', 'Thiocolchicoside (4mg)') -> Associated Side Effects: {'Flatulence ', 'Stomach pain', 'Diarrhea ', 'Feet swelling', 'Swelling of', 'Indigestion ', 'Flu like'}
# Itemset: ('Diacerein (50mg)', 'Glucosamine (750mg)') -> Associated Side Effects: {'Nausea ', 'Diarrhea ', 'Constipation ', 'Urine discoloration', 'Heartburn ', 'Indigestion ', 'Heartburn'}
# Itemset: ('Clopidogrel (75mg)', 'Rosuvastatin (10mg)') -> Associated Side Effects: {'Headache ', 'Nosebleeds ', 'Abdominal pain', 'Stomach pain', 'Diarrhea ', 'Constipation ', 'Increased glucose', 'Gastrointestinal bleeding', 'Bruise ', 'Increased bleeding', 'Weakness ', 'Indigestion ', 'Nausea', 'Increased liver', 'Muscle pain', 'Dizziness '}
# Itemset: ('Glucosamine (750mg)', 'Methyl Sulfonyl Methane (250mg)') -> Associated Side Effects: {'Nausea ', 'Diarrhea ', 'Constipation ', 'Urine discoloration', 'Heartburn ', 'Indigestion '}
# Itemset: ('Diacerein (50mg)', 'Methyl Sulfonyl Methane (250mg)') -> Associated Side Effects: {'Nausea ', 'Diarrhea ', 'Constipation ', 'Urine discoloration', 'Heartburn ', 'Indigestion '}
# Itemset: ('Diacerein (50mg)', 'Glucosamine (750mg)', 'Methyl Sulfonyl Methane (250mg)') -> Associated Side Effects: {'Nausea ', 'Diarrhea ', 'Constipation ', 'Urine discoloration', 'Heartburn ', 'Indigestion '}
# Itemset: ('Hydrochlorothiazide (12.5mg)', 'Olmesartan Medoxomil (20mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Peripheral edema', 'Fatigue ', 'Tiredness ', 'Diarrhea ', 'Edema swelling', 'Chest pain', 'Weakness ', 'Nasopharyngitis inflammation', 'Urinary tract', 'Upper respiratory', 'Muscle spasm', 'Dizziness ', 'Joint swelling'}
# Itemset: ('Levocetirizine (2.5mg/5ml)', 'Montelukast (4mg/5ml)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Fatigue ', 'Diarrhea ', 'Vomiting', 'Skin rash', 'Sleepiness ', 'Dryness in', 'Rash '}
# Itemset: ('Clobetasol (0.05% w/w)', 'Miconazole (2% w/w)') -> Associated Side Effects: {'Burning sensation', 'Application site', 'Irritation', 'Irritation ', 'Thinning of', 'Skin pain', 'Itching '}
# Itemset: ('Clobetasol (0.05% w/w)', 'Neomycin (0.5% w/w)') -> Associated Side Effects: {'Burning sensation', 'Application site', 'Irritation', 'Irritation ', 'Thinning of', 'Itching', 'Itching ', 'Stinging sensation'}
# Itemset: ('Miconazole (2% w/w)', 'Neomycin (0.5% w/w)') -> Associated Side Effects: {'Burning sensation', 'Skin peeling', 'Application site', 'Irritation', 'Irritation ', 'Thinning of', 'Itching '}
# Itemset: ('Clobetasol (0.05% w/w)', 'Miconazole (2% w/w)', 'Neomycin (0.5% w/w)') -> Associated Side Effects: {'Burning sensation', 'Application site', 'Irritation', 'Irritation ', 'Thinning of', 'Itching '}
# Itemset: ('Glimepiride (2mg)', 'Pioglitazone (15mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Leg pain', 'Flatulence ', 'Bronchitis inflammation', 'Diarrhea ', 'Anemia low', 'Edema swelling', 'Vomiting ', 'Decreased blood', 'Infection ', 'Accidental injury', 'Urinary tract', 'Hypoglycemia low', 'Cold symptoms', 'Dizziness '}
# Itemset: ('Glimepiride (2mg)', 'Metformin (500mg)', 'Pioglitazone (15mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Flatulence ', 'Bronchitis inflammation', 'Diarrhea ', 'Anemia low', 'Edema swelling', 'Vomiting ', 'Hypoglycemia low', 'Dizziness '}
# Itemset: ('Ispaghula (3.5gm)', 'Lactitol (10gm)') -> Associated Side Effects: {'Flatulence', 'Stomach cramp', 'Bloating '}
# Itemset: ('Gliclazide (80mg)', 'Metformin (500mg)') -> Associated Side Effects: {'Nausea ', 'Respiratory tract', 'Headache ', 'Stomach pain', 'Flatulence ', 'Diarrhea ', 'Bronchitis inflammation', 'Anemia low', 'Vomiting ', 'Edema swelling', 'Upper respiratory', 'Taste change', 'Flatulence', 'Hypoglycemia low', 'Skin rash', 'Dizziness '}
# Itemset: ('Gabapentin (300mg)', 'Methylcobalamin (500mcg)') -> Associated Side Effects: {'Sleepiness ', 'Uncoordinated body', 'Dizziness ', 'Tiredness '}
# Itemset: ('Cefpodoxime Proxetil (200mg)', 'Clavulanic Acid (125mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Abdominal pain', 'Diarrhea ', 'Fungal infection', 'Vaginal infection', 'Rash '}
# Itemset: (' Dutasteride (0.5mg)', 'Tamsulosin  (0.4mg)') -> Associated Side Effects: {'Decreased libido', 'Breast enlargement', 'Ejaculation disorder', 'Orthostatic hypotension', 'Breast tenderness', 'Impotence '}
# Itemset: ('Chlorthalidone (12.5mg)', 'Cilnidipine (10mg)') -> Associated Side Effects: {'Increased uric', 'Diarrhea ', 'Constipation ', 'Decreased blood', 'Altered blood', 'Slow heart', 'Palpitations ', 'Decreased sodium', 'Nausea ', 'Decreased potassium', 'Numbness of', 'Tiredness ', 'Taste change', 'Decreased magnesium', 'Dizziness ', 'Headache ', 'Upset stomach', 'Vomiting ', 'Increased blood', 'Cold extremities', 'Glucose intolerance', 'Weakness ', 'Flushing sense', 'Sleepiness ', 'Ankle swelling'}
# Itemset: ('Glibenclamide (5mg)', 'Metformin (500mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Flatulence ', 'Diarrhea ', 'Anemia low', 'Vomiting ', 'Flatulence', 'Hypoglycemia low', 'Weight gain'}
# Itemset: ('Beclometasone (0.025% w/w)', 'Clotrimazole (1% w/w)') -> Associated Side Effects: {'Dry skin', 'Application site', 'Burning sensation', 'Paresthesia tingling'}
# Itemset: ('Clobetasol (0.05% w/w)', 'Salicylic Acid (3% w/w)') -> Associated Side Effects: {'Skin peeling', 'Application site', 'Dry skin', 'Thinning of'}
# Itemset: ('Hydroquinone (2% w/w)', 'Mometasone (0.1% w/w)') -> Associated Side Effects: {'Application site'}
# Itemset: ('Mometasone (0.1% w/w)', 'Tretinoin (0.025% w/w)') -> Associated Side Effects: {'Application site'}
# Itemset: ('Hydroquinone (2% w/w)', 'Mometasone (0.1% w/w)', 'Tretinoin (0.025% w/w)') -> Associated Side Effects: {'Application site'}
# Itemset: ('Domperidone (30mg)', 'Esomeprazole (40mg)') -> Associated Side Effects: {'Headache', 'Stomach pain', 'Flatulence ', 'Diarrhea ', 'Dryness in'}
# Itemset: ('Esomeprazole (40mg)', 'Levosulpiride (75mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Sleepiness', 'Upset stomach', 'Stomach pain', 'Diarrhea ', 'Flatulence ', 'Constipation ', 'Vomiting '}
# Itemset: ('Mefenamic Acid (250mg)', 'Tranexamic Acid (500mg)') -> Associated Side Effects: {'Nausea ', 'Sinus inflammation', 'Headache ', 'Tiredness ', 'Stomach pain', 'Diarrhea ', 'Anemia low', 'Musculoskeletal bone', 'Vomiting ', 'Loss of', 'Nasal congestion', 'Heartburn ', 'Indigestion ', 'Sinus pain'}
# Itemset: ('Fusidic Acid (2% w/w)', 'Mometasone (0.1% w/w)') -> Associated Side Effects: {'Viral infection', 'Headache ', 'Nosebleeds ', 'Burning sensation', 'Irritation ', 'Sore throat', 'Vomiting', 'Upper respiratory', 'Itching '}
# Itemset: ('Chlorthalidone (12.5mg)', 'Telmisartan (80mg)') -> Associated Side Effects: {'Increased uric', 'Sinus infection', 'Diarrhea ', 'Increased glucose', 'Fatigue ', 'Gastrointestinal disturbance', 'Impotence', 'Increased liver', 'Edema swelling', 'Postural hypotension', 'Dizziness ', 'Electrolyte imbalance', 'Headache ', 'Urticaria ', 'Breathlessness ', 'Increased blood', 'Muscle cramp', 'Back pain', 'Visual disturbance', 'Skin ulcer', 'Sleepiness '}
# Itemset: ('  Human Insulin/Soluble Insulin (30%)', 'Insulin Isophane/NPH   (70%)') -> Associated Side Effects: {'Injection site', 'Hypoglycemia low', 'Weight gain'}
# Itemset: ('Metformin (500mg)', 'Teneligliptin (20mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Bloating ', 'Diarrhea ', 'Vomiting ', 'Flatulence', 'Hypoglycemia low'}
# Itemset: ('Mometasone (0.1% w/w)', 'Terbinafine (1% w/w)') -> Associated Side Effects: {'Skin atrophy', 'Burning sensation', 'Skin peeling', 'Application site', 'Skin exfoliation'}
# Itemset: ('Hydrochlorothiazide (12.5mg)', 'Telmisartan (80mg)') -> Associated Side Effects: {'Nausea ', 'Sinus inflammation', 'Peripheral edema', 'Fatigue ', 'Diarrhea ', 'Visual disturbance', 'Upper respiratory', 'Flu like', 'Ankle swelling', 'Dizziness ', 'Mood changes'}
# Itemset: ('Metformin (1000mg)', 'Teneligliptin (20mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Bloating ', 'Diarrhea ', 'Vomiting ', 'Flatulence', 'Hypoglycemia low'}
# Itemset: (' Vildagliptin (50mg)', 'Metformin  (500mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Trembling ', 'Hypoglycemia low', 'Dizziness ', 'Weight gain'}
# Itemset: (' Vildagliptin (50mg)', 'Metformin  (1000mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Trembling ', 'Hypoglycemia low', 'Dizziness ', 'Weight gain'}
# Itemset: ('Glimepiride (1mg)', 'Pioglitazone (15mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Flatulence ', 'Bronchitis inflammation', 'Diarrhea ', 'Anemia low', 'Edema swelling', 'Vomiting ', 'Hypoglycemia low', 'Dizziness '}
# Itemset: ('Glimepiride (1mg)', 'Metformin (500mg)', 'Pioglitazone (15mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Flatulence ', 'Bronchitis inflammation', 'Diarrhea ', 'Anemia low', 'Edema swelling', 'Vomiting ', 'Hypoglycemia low', 'Dizziness '}
# Itemset: ('Aspirin (75mg)', 'Rosuvastatin (10mg)') -> Associated Side Effects: {'Nausea ', 'Weakness', 'Nosebleeds ', 'Headache ', 'Abdominal pain', 'Diarrhea ', 'Constipation ', 'Gastrointestinal bleeding', 'Bruise ', 'Increased bleeding', 'Weakness ', 'Indigestion ', 'Nausea', 'Muscle pain'}
# Itemset: ('Aspirin (75mg)', 'Clopidogrel (75mg)', 'Rosuvastatin (10mg)') -> Associated Side Effects: {'Nosebleeds ', 'Headache ', 'Abdominal pain', 'Diarrhea ', 'Gastrointestinal bleeding', 'Bruise ', 'Increased bleeding', 'Weakness ', 'Indigestion ', 'Nausea', 'Muscle pain'}
# Itemset: ('Levocetirizine (2.5mg)', 'Montelukast (4mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Fatigue ', 'Diarrhea ', 'Vomiting', 'Skin rash', 'Sleepiness ', 'Dryness in', 'Rash '}
# Itemset: ('Ofloxacin (200mg)', 'Ornidazole (500mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Vomiting ', 'Insomnia difficulty', 'Vaginal inflammation', 'Dizziness ', 'Itching ', 'Diarrhea'}
# Itemset: ('Loteprednol etabonate (0.5% w/v)', 'Moxifloxacin (0.5% w/v)') -> Associated Side Effects: {'Eye discomfort', 'Eye irritation'}
# Itemset: ('Clopidogrel (75mg)', 'Rosuvastatin (20mg)') -> Associated Side Effects: {'Headache ', 'Nosebleeds ', 'Abdominal pain', 'Stomach pain', 'Diarrhea ', 'Constipation ', 'Increased glucose', 'Gastrointestinal bleeding', 'Bruise ', 'Increased bleeding', 'Weakness ', 'Indigestion ', 'Nausea', 'Increased liver', 'Muscle pain', 'Dizziness '}
# Itemset: ('Aspirin (75mg)', 'Rosuvastatin (20mg)') -> Associated Side Effects: {'Nausea ', 'Weakness', 'Nosebleeds ', 'Headache ', 'Abdominal pain', 'Diarrhea ', 'Constipation ', 'Gastrointestinal bleeding', 'Bruise ', 'Increased bleeding', 'Weakness ', 'Indigestion ', 'Nausea', 'Muscle pain'}
# Itemset: ('Aspirin (75mg)', 'Clopidogrel (75mg)', 'Rosuvastatin (20mg)') -> Associated Side Effects: {'Nosebleeds ', 'Headache ', 'Abdominal pain', 'Diarrhea ', 'Gastrointestinal bleeding', 'Bruise ', 'Increased bleeding', 'Weakness ', 'Indigestion ', 'Nausea', 'Muscle pain'}
# Itemset: ('Chlorthalidone (12.5mg)', 'Olmesartan Medoxomil (20mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Tiredness ', 'Upset stomach', 'Palpitations ', 'Diarrhea ', 'Decreased blood', 'Increased blood', 'Altered blood', 'Glucose intolerance', 'Taste change', 'Weakness ', 'Flushing sense', 'Sleepiness ', 'Ankle swelling', 'Dizziness ', 'Electrolyte imbalance'}
# Itemset: ('Chlorthalidone (12.5mg)', 'Olmesartan Medoxomil (40mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Tiredness ', 'Upset stomach', 'Palpitations ', 'Diarrhea ', 'Decreased blood', 'Increased blood', 'Altered blood', 'Glucose intolerance', 'Taste change', 'Weakness ', 'Flushing sense', 'Sleepiness ', 'Ankle swelling', 'Dizziness ', 'Electrolyte imbalance'}
# Itemset: ('Amlodipine (5mg)', 'Olmesartan Medoxomil (20mg)') -> Associated Side Effects: {'Diarrhea ', 'Altered blood', 'Fatigue ', 'Palpitations ', 'Urinary tract', 'Upper respiratory', 'Muscle spasm', 'Nausea ', 'Tiredness ', 'Taste change', 'Nasopharyngitis inflammation', 'Increased potassium', 'Peripheral edema', 'Dizziness ', 'Headache ', 'Upset stomach', 'Increased blood', 'Glucose intolerance', 'Flushing sense', 'Sleepiness ', 'Ankle swelling', 'Joint swelling'}
# Itemset: ('Hydrochlorothiazide (12.5mg)', 'Olmesartan Medoxomil (40mg)') -> Associated Side Effects: {'Nausea ', 'Headache ', 'Peripheral edema', 'Fatigue ', 'Tiredness ', 'Diarrhea ', 'Edema swelling', 'Chest pain', 'Weakness ', 'Nasopharyngitis inflammation', 'Urinary tract', 'Upper respiratory', 'Muscle spasm', 'Dizziness ', 'Joint swelling'}
# Itemset: ('Amlodipine (5mg)', 'Olmesartan Medoxomil (40mg)') -> Associated Side Effects: {'Diarrhea ', 'Altered blood', 'Fatigue ', 'Palpitations ', 'Urinary tract', 'Upper respiratory', 'Muscle spasm', 'Nausea ', 'Tiredness ', 'Taste change', 'Nasopharyngitis inflammation', 'Increased potassium', 'Peripheral edema', 'Dizziness ', 'Headache ', 'Upset stomach', 'Increased blood', 'Glucose intolerance', 'Flushing sense', 'Sleepiness ', 'Ankle swelling', 'Joint swelling'}
# Itemset: ('Chlorthalidone (6.25mg)', 'Telmisartan (40mg)') -> Associated Side Effects: {'Increased uric', 'Sinus infection', 'Diarrhea ', 'Increased glucose', 'Altered blood', 'Fatigue ', 'Palpitations ', 'Gastrointestinal disturbance', 'Impotence', 'Increased liver', 'Tiredness ', 'Edema swelling', 'Postural hypotension', 'Taste change', 'Dizziness ', 'Electrolyte imbalance', 'Headache ', 'Urticaria ', 'Upset stomach', 'Breathlessness ', 'Increased blood', 'Muscle cramp', 'Back pain', 'Glucose intolerance', 'Visual disturbance', 'Flushing sense', 'Skin ulcer', 'Sleepiness ', 'Ankle swelling'}
